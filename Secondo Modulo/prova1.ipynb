# %%
print("Ciao")
# Out:
# Ciao

# %%
# !ls
# Out:
# "ls" non � riconosciuto come comando interno o esterno,
#  un programma eseguibile o un file batch.

# %%
# %timeit [n*n for n in range(200)]
# Out:
# 10.1 μs ± 371 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
id_lavoro = 101
nome_azienda = 'DataWiz Inc.'
titolo_lavoro = 'Data Analyst'
stipendio_lavoro = 125000
lavoro_da_casa = True
