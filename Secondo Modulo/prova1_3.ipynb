# %%
import random
lista = [random.randint(5, 15) for _ in range(20)]
print(lista)
# Out:
# [12, 14, 8, 12, 13, 11, 14, 15, 6, 13, 9, 7, 15, 15, 6, 13, 13, 5, 10, 11]

# %%
# %%timeit

statistics.mean(lista)
# Out:
# 16.8 μs ± 940 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
import numpy as np
statistics.mean(lista), np.mean(lista)
# Out:
# (11.1, np.float64(11.1))

# %%
#ndarray
a = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
import numpy as np
np.array([1,2.2, 3,4,5]).dtype
#oppure
a = np.array([1,2,3,4,5])
a.dtype
# Out:
# dtype('int64')

# %%
import numpy as np
zeri = np.zeros((3))
print(zeri)
# Out:
# [0. 0. 0.]

# %%
copia = np.zeros_like(a)
copia
# Out:
# array([0, 0, 0, 0, 0])
